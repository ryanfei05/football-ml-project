# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('PLmatches.csv')
df
# Out:
#             date   time            comp         round  day venue result   gf  \
# 0     2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1     2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2     2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3     2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4     2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ...          ...    ...             ...           ...  ...   ...    ...  ...
# 5893  2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W  1.0
# 5894  2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home      D  2.0
# 5895  2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W  1.0
# 5896  2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home      W  1.0
# 5897  2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L  0.0
#
# ...

# %%
# Ways to describe
df.head() #first 5 rows
df.tail() #last 5 rows
df.columns #field, not method
df.index #index
#df.info()
#df.describe()
df.nunique()
#df["day"].unique() #array(['Sat', 'Sun', 'Wed', 'Thu', 'Tue', 'Fri', 'Mon'], dtype=object)
#df.shape #(5898, 28)
# Out:
# date              903
# time               25
# comp                1
# round              38
# day                 7
# venue               2
# result              3
# gf                 10
# ga                 10
# opponent           31
# xg                 53
# xga                53
# poss               65
# attendance       2266
# captain           264
# formation          22
# opp formation      21
# referee            39
# match report        1
# notes               0
# sh                 38
# sot                17
# dist              209
# fk                  6
# pk                  4
# pkatt               4
# season              8
# team               31
# dtype: int64

# %%
df.sample(5)
# Out:
#             date   time            comp         round  day venue result   gf  \
# 2553  2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
# 2412  2021-11-06  17:30  Premier League  Matchweek 11  Sat  Home      D  1.0
# 5161  2018-01-20  17:30  Premier League  Matchweek 24  Sat  Home      W  3.0
# 4793  2019-04-27  15:00  Premier League  Matchweek 36  Sat  Home      L  1.0
# 3014  2020-10-18  19:15  Premier League   Matchweek 5  Sun  Home      L  0.0
#
#        ga        opponent  ...  match report  notes    sh  sot  dist   fk pk  \
# 2553  0.0  Manchester Utd  ...  Match Report    NaN   6.0  3.0  14.1  0.0  0
# 2412  1.0   Newcastle Utd  ...  Match Report    NaN  13.0  4.0  17.9  0.0  1
# 5161  1.0   Newcastle Utd  ...  Match Report    NaN  20.0  8.0  18.2  1.0  1
# 4793  2.0          Wolves  ...  Match Report    NaN  10.0  1.0  17.6  0.0  0
# 3014  1.0     Aston Villa  ...  Match Report    NaN  11.0  5.0  19.2  2.0  0
#
# ...

# %%
#df.loc[row, column], ie
df.loc[10]
df.loc[10, 'result'] #'W'
df.loc[17:25, ['opponent', 'team']]
df.iloc[0:5,0:3]
# Out:
#          date   time            comp
# 0  2024-08-17  12:30  Premier League
# 1  2024-08-25  16:30  Premier League
# 2  2024-09-01  16:00  Premier League
# 3  2024-09-14  15:00  Premier League
# 4  2024-09-21  15:00  Premier League

# %%
df.sort_values(["sot", "sh"], ascending=False)
# Out:
#             date   time            comp         round  day venue result   gf  \
# 34    2024-09-28  15:00  Premier League   Matchweek 6  Sat  Home      W  4.0
# 2114  2021-12-14  20:00  Premier League  Matchweek 17  Tue  Home      W  7.0
# 599   2024-02-05  20:00  Premier League  Matchweek 23  Mon  Away      W  3.0
# 811   2023-09-24  16:30  Premier League   Matchweek 6  Sun  Away      W  8.0
# 5342  2017-12-02  17:30  Premier League  Matchweek 15  Sat  Home      L  1.0
# ...          ...    ...             ...           ...  ...   ...    ...  ...
# 3989  2020-06-22  20:00  Premier League  Matchweek 30  Mon  Away      L  0.0
# 5717  2017-10-28  15:00  Premier League  Matchweek 10  Sat  Away      L  0.0
# 3356  2020-10-18  14:00  Premier League   Matchweek 5  Sun  Home      D  1.0
# 4900  2019-03-02  15:00  Premier League  Matchweek 29  Sat  Home      L  0.0
# 5813  2018-03-10  15:00  Premier League  Matchweek 30  Sat  Away      D  0.0
#
# ...

# %%
df.loc[df["season"] == 2024]
df.query("season == 2018 and result == 'W'")["team"].value_counts()
# Out:
# team
# Manchester City             32
# Liverpool                   30
# Tottenham Hotspur           23
# Chelsea                     21
# Arsenal                     21
# Manchester United           19
# Wolverhampton Wanderers     16
# Everton                     15
# Leicester City              15
# West Ham United             15
# Crystal Palace              14
# Watford                     14
# Bournemouth                 13
# Newcastle United            12
# Burnley                     11
# Cardiff City                10
# Southampton                  9
# Brighton and Hove Albion     9
# Fulham                       7
# Huddersfield Town            3
# Name: count, dtype: int64

# %%
df['full season'] = np.where(df['season'] == 2024, True, False)
df['datetime'] = pd.to_datetime(df['date'])
df['daydt'] = df['datetime'].dt.day_name()
df['leapyear'] = df['datetime'].dt.is_leap_year
df
# Out:
#             date   time            comp         round  day venue result   gf  \
# 0     2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1     2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2     2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3     2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4     2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ...          ...    ...             ...           ...  ...   ...    ...  ...
# 5893  2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W  1.0
# 5894  2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home      D  2.0
# 5895  2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W  1.0
# 5896  2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home      W  1.0
# 5897  2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L  0.0
#
# ...

# %%
df['test'] = df['result'].apply(lambda x: 'Win' if (x == 'W') else ('Lose' if (x == 'L') else ('Draw')))

mancity = df.query("team == 'Manchester City'")
manu = df.query("team == 'Manchester United'")
pd.concat([manu, mancity])
# Out:
#             date   time            comp         round  day venue result   gf  \
# 346   2024-08-16  20:00  Premier League   Matchweek 1  Fri  Home      W  1.0
# 347   2024-08-24  12:30  Premier League   Matchweek 2  Sat  Away      L  1.0
# 348   2024-09-01  16:00  Premier League   Matchweek 3  Sun  Home      L  0.0
# 349   2024-09-14  12:30  Premier League   Matchweek 4  Sat  Away      W  3.0
# 350   2024-09-21  17:30  Premier League   Matchweek 5  Sat  Away      D  0.0
# ...          ...    ...             ...           ...  ...   ...    ...  ...
# 5171  2018-04-22  16:30  Premier League  Matchweek 35  Sun  Home      W  5.0
# 5172  2018-04-29  14:15  Premier League  Matchweek 36  Sun  Away      W  4.0
# 5173  2018-05-06  13:30  Premier League  Matchweek 37  Sun  Home      D  0.0
# 5174  2018-05-09  20:00  Premier League  Matchweek 31  Wed  Home      W  3.0
# 5175  2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      W  1.0
#
# ...

# %%
df.groupby('team')['result'].value_counts()
# Out:
# team                     result
# Arsenal                  W         164
#                          L          73
#                          D          58
# Aston Villa              W          88
#                          L          86
#                                   ...
# West Ham United          W         104
#                          D          68
# Wolverhampton Wanderers  L         110
#                          W          89
#                          D          58
# Name: count, Length: 93, dtype: int64

# %%
plt.boxplot(df['sh'], vert=False)

plt.ylabel('Variable')
plt.xlabel('Shots')
plt.title('Box Plot')
plt.show()

# %%
df.shape
# Out:
# (5898, 33)
